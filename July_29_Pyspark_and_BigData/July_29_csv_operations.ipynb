# %%
csv_data= """
Name,Math,Science,English
Amit,78,85,74
Priya,92,89,96
Kiran,65,70,60
Anita,88,95,90
Ravi,55,60,58
"""
with open('students.csv','w')as file:
  file.write(csv_data)

# %%
from google.colab import files
files.download('students.csv')

# %%
import pandas as pd

df = pd.read_csv('/content/students.csv')
#print(df)
print(df.head(3))
# Out:
#     Name  Math  Science  English
# 0   Amit    78       85       74
# 1  Priya    92       89       96
# 2  Kiran    65       70       60

# %%
# 2. Average scores

df['Average']=df[['Math','Science','English']].mean(axis=1) # axis =1 across row
print(df['Average'].max())
top= df[df['Average']==df['Average'].max()]
print(top)
# Out:
# 92.33333333333333
#     Name  Math  Science  English    Average
# 1  Priya    92       89       96  92.333333

# %%
# 3.Filter Students
# 3.1 more than 80 in Science
sci_top= df[df['Science']>80] # using only df['Science']>80 gives true or false values
print('Students with more than 80 in science:\n',sci_top)
# Out:
# Students with more than 80 in science:
#      Name  Math  Science  English    Average
# 0   Amit    78       85       74  79.000000
# 1  Priya    92       89       96  92.333333
# 3  Anita    88       95       90  91.000000

# %%
# 3.2 all students with an average score below 70.
avg_below = df[df['Average']<70]
print('Students with average less than 70: \n',avg_below)
# Out:
# Students with average less than 70:
#      Name  Math  Science  English    Average
# 2  Kiran    65       70       60  65.000000
# 4   Ravi    55       60       58  57.666667

# %%
# 4.Sort students by English score (descending) and print the top 3.
English_top = df.sort_values(by='English',ascending=False)
print(English_top.head(3))
# Out:
#     Name  Math  Science  English    Average
# 1  Priya    92       89       96  92.333333
# 3  Anita    88       95       90  91.000000
# 0   Amit    78       85       74  79.000000

# %%
# 5.1 Create a bar chart showing students’ names on the X-axis and their average
#scores on the Y-axis.
import matplotlib.pyplot as plt
df['Average']=df[['Math','Science','English']].mean(axis=1)

plt.figure(figsize=(8,5))
plt.bar(df['Name'],df['Average'],color='teal')
plt.xlabel('Students')
plt.ylabel('Average marks')
plt.xticks(rotation=30)
plt.grid(True)
plt.show()

# %%
# 5.2 Create a line chart for all students’ scores in Math, Science, and English
import matplotlib.pyplot as plt
df.set_index('Name' , inplace=False)
df[['Math','Science','English']].plot(kind='line', marker='d')

plt.title('Students scores')
plt.xlabel('Students')
plt.ylabel('Scores')
plt.grid(True)
plt.tight_layout()

# %%
print(df)
# Out:
#     Name  Math  Science  English
# 0   Amit    78       85       74
# 1  Priya    92       89       96
# 2  Kiran    65       70       60
# 3  Anita    88       95       90
# 4   Ravi    55       60       58

# %%
# Bonus 1
total= df[['Math','Science','English']].sum()
print(total.max())
# Out:
# 399

# %%
# Bonus 2
#print(df)
df['Average']= df[['Math','Science','English']].mean(axis=1)
df.to_csv('students_summary.csv')
